# %%
import geopandas as gpd
import pyproj

# %%
# read shapefile with river ID 0
shp=gpd.read_file('/home/paulc600/scratch/PRMS/PRMS Kathy Setup/20230605_gm_byHWobs_st_mary_and_milk_rivers/GIS/model_npoigages.shp')

# %%
shp
# Out:
#      gage_id  nhm_seg                          geometry
# 0   05014300    30926  POINT (-1305166.793 2987279.908)
# 1    05AE904    30929  POINT (-1291619.971 3010721.011)
# 2    05AE005    30899  POINT (-1260982.660 3016632.185)
# 3    05AE002    30911  POINT (-1268960.248 3026822.434)
# 4    05AE043    30898  POINT (-1267027.019 3013570.972)
# 5   05016000    30914  POINT (-1293559.439 2989187.322)
# 6   05014500    30925  POINT (-1304684.330 2987755.502)
# 7   05017500    30906  POINT (-1286743.383 2988423.267)
# 8   05014000    30934  POINT (-1307958.287 2985170.706)
# 9   06142400    47928   POINT (-996288.170 2914365.346)
# 10  06139500    47849  POINT (-1025798.153 2915390.336)
# 11   11AB118    47920   POINT (-998858.642 3010658.332)
# 12  06151500    47804   POINT (-981363.707 2917022.118)
# 13  06174500    30936   POINT (-774844.195 2833253.740)
# 14   11AB103    48113  POINT (-1018750.703 2966811.942)
# 15   11AB083    47859  POINT (-1012629.421 2962021.786)
# 16   11AC023    47823   POINT (-881904.160 2988932.097)
# 17   11AB117    48160  POINT (-1023397.096 3034901.175)
# 18   11AC001    47862   POINT (-939954.856 3008564.347)
# 19  06132200    48110  POINT (-1269323.341 2976819.385)
# 20   11AC025    47960   POINT (-860634.228 2975228.774)
# 21   11AC017    47887   POINT (-958666.296 3008636.653)
# 22   11AB101    47878   POINT (-991417.510 2975660.051)
# 23   11AC051    47807   POINT (-861156.260 2962540.916)
# 24   11AB075    48098   POINT (-977188.672 2956368.800)
# 25   11AA039    48129  POINT (-1179592.553 3013441.348)
# 26   11AA001    48070  POINT (-1250256.387 3002557.585)
# 27   11AB008    47946  POINT (-1018394.958 2973086.301)
# 28   11AB082    47910  POINT (-1029007.033 2986386.166)
# 29   11AB009    48101  POINT (-1029859.249 3010718.545)
# 30   11AC062    47810   POINT (-868147.274 2975753.023)
# 31   11AB096    47896   POINT (-995372.420 2989861.332)
# 32   11AA029    48037  POINT (-1135625.520 2983399.993)
# 33   11AA025    47911  POINT (-1219213.534 2995842.985)
# 34   11AA005    47857  POINT (-1182243.313 3003551.203)
# 35   11AB108    48003  POINT (-1017238.693 2987140.509)
# 36  06169500    47901   POINT (-801694.498 2930414.827)
# 37  06133500    48146  POINT (-1258012.797 2997451.362)
# 38  06135000    47811  POINT (-1064752.681 2966240.933)
# 39  06174000    47879   POINT (-796045.898 2838404.254)
# 40  06164510    30948   POINT (-832875.131 2881890.954)
# 41  06154550    47921   POINT (-922364.383 2879611.542)
# 42  06137400    48040  POINT (-1035362.114 2872134.243)
# 43  06154100    30966   POINT (-946545.331 2897161.288)
# 44  06140500    47787  POINT (-1014679.527 2913409.861)
# 45  06167500    47831   POINT (-833076.394 2873484.300)
# 46  06166000    47839   POINT (-857374.148 2879301.732)
# 47  06137570    47961  POINT (-1033489.139 2886698.478)
# 48  06154400    47963   POINT (-948767.117 2866883.018)
# 49   11AA026    48016  POINT (-1046815.855 2976636.624)
# 50  06154410    48157   POINT (-950858.948 2838167.113)

# %%
# Check the current CRS
current_crs = shp.crs
print("Current CRS:", current_crs)
# Out:
# Current CRS: PROJCS["USA_Contiguous_Albers_Equal_Area_Conic_USGS_version",GEOGCS["NAD83",DATUM["North_American_Datum_1983",SPHEROID["GRS 1980",6378137,298.257222101,AUTHORITY["EPSG","7019"]],AUTHORITY["EPSG","6269"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4269"]],PROJECTION["Albers_Conic_Equal_Area"],PARAMETER["latitude_of_center",23],PARAMETER["longitude_of_center",-96],PARAMETER["standard_parallel_1",29.5],PARAMETER["standard_parallel_2",45.5],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["ESRI","102039"]]

# %%
# Convert to EPSG:4326 if not already in that CRS
target_crs = 'EPSG:4326'
if current_crs != target_crs:
    shp = shp.to_crs(target_crs)
    print("Converted to CRS:", shp.crs)
# Out:
# Converted to CRS: EPSG:4326

# %%
# Save the modified GeoDataFrame to a new shapefile
output_path = '/home/paulc600/local/Modified_gauge.shp'
shp.to_file(output_path)

# %%
# Read the modified shapefile into a new GeoDataFrame to check that it has been switched
modified_shapefile_path = '/home/paulc600/local/Modified_gauge.shp'
modified_gdf = gpd.read_file(modified_shapefile_path)

# %%
# Check the CRS of the modified GeoDataFrame
modified_crs = modified_gdf.crs
print("Modified CRS:", modified_crs)
# Out:
# Modified CRS: epsg:4326
