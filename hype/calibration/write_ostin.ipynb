# %%
import pandas as pd
import numpy as np
import string

# %% [markdown]
# # Read the content of the file using ISO-8859-1 encoding
# with open('./old_par.txt', 'r', encoding='ISO-8859-1') as f:
#     content = f.read()

# %% [markdown]
# # Write the content back to the file using UTF-8 encoding
# with open('./old_par.txt', 'w', encoding='utf-8') as f:
#     f.write(content)

# %%
# Read the file into a DataFrame, ignoring lines starting with '#'
#old_par= pd.read_csv('./data/par_text.txt', comment='!', delimiter='\t', header= None, index_col=0)

# %%
# Read the file into a DataFrame, ignoring lines starting with '#'
par = pd.read_csv('./data/par.txt', comment='!', delimiter='\t', header= None, index_col=0)

# %%
# read cal params
cal_params= pd.read_csv('./cal_param.txt', delimiter='\t',header= None,index_col=0)

# %%
cal_params
# Out:
#                     1      2       3     4     5     6
# 0
# ttmp         2.909494 -3.000    3.00  none  none  none
# cmlt         4.220418  1.000   10.00  none  none  none
# kc           1.276205  0.400    1.30  none  none  none
# alb          0.200000  0.100    0.50  none  none  none
# srrcs        0.175497  0.010    0.20  none  none  none
# rrcs1        0.073282  0.050    0.60  none  none  none
# rrcs2        0.002159  0.001    0.20  none  none  none
# bcosby      13.122820  1.000   20.00  none  none  none
# bfroznsoil   2.915200  1.000    5.00  none  none  none
# srrate       0.200000  0.050    0.50  none  none  none
# wcwp1        0.214000  0.010    0.50  none  none  none
# wcwp2        0.256000  0.010    0.50  none  none  none
# wcwp3        0.058000  0.010    0.50  none  none  none
# wcfc1        0.175800  0.050    0.50  none  none  none
# wcfc2        0.196600  0.050    0.50  none  none  none
# wcfc3        0.207500  0.050    0.50  none  none  none
# wcep1        0.416800  0.010    0.90  none  none  none
# wcep2        0.277300  0.010    0.90  none  none  none
# wcep3        0.300400  0.010    0.90  none  none  none
# rrcs3        0.080346  0.000    0.10  none  none  none
# mperc1      60.000000  5.000  120.00  none  none  none
# mperc2      60.000000  5.000  120.00  none  none  none
# lp           0.771000  0.500    1.00  none  none  none
# epotdist     5.667900  2.000    6.00  none  none  none
# rivvel       0.318715  0.100   10.00  none  none  none
# damp         0.900375  0.100    0.95  none  none  none
# wetrate      3.170000  0.100   15.00  none  none  none
# wetexp       4.940000  0.250    5.00  none  none  none
# iwetw0       4.360000  0.500   15.00  none  none  none
# macrate      0.200000  0.000    0.50  none  none  none
# mactrinf    50.000000  1.000  100.00  none  none  none
# mactrsm      0.200000  0.000    0.80  none  none  none

# %%
# Convert index of cal_params to string
cal_params.index = cal_params.index.astype(str)

# Convert index of par to string
par.index = par.index.astype(str)

# %%
# Create an empty list to record strings being written
strings_written = []

# %%
# Define a mapping of column names to letters
column_letters = {col: letter for col, letter in zip(par.columns, string.ascii_uppercase)}

# Iterate through the index of the par DataFrame
for par_index in par.index:
    # Check if the index exists in cal_params
    if par_index in cal_params.index:
        # Get the row index of the value in cal_params DataFrame
        cal_params_row_index = cal_params.index.get_loc(par_index)
        # Iterate through the columns of par DataFrame
        for col in par.columns:
            # Update the value in the par DataFrame
            par_value = par.at[par_index, col]
            # Stop writing if a value of nan is found
            if pd.isna(par_value):
                break
            else:
                # Get the corresponding letter for the column name
                letter = column_letters[col]
                new_string = f'___{par_index}{letter}'  # Construct the new string with letter instead of {col}
                strings_written.append(new_string)  # Append the new string to the list
                par.at[par_index, col] = new_string  # Update the value in the par DataFrame

# %%
ostin = pd.DataFrame(index=strings_written, columns=cal_params.columns)

# %%
ostin
# Out:
#                1    2    3    4    5    6
# ___ttmpA     NaN  NaN  NaN  NaN  NaN  NaN
# ___ttmpB     NaN  NaN  NaN  NaN  NaN  NaN
# ___ttmpC     NaN  NaN  NaN  NaN  NaN  NaN
# ___ttmpD     NaN  NaN  NaN  NaN  NaN  NaN
# ___ttmpE     NaN  NaN  NaN  NaN  NaN  NaN
# ...          ...  ...  ...  ...  ...  ...
# ___mactrsmM  NaN  NaN  NaN  NaN  NaN  NaN
# ___mactrsmN  NaN  NaN  NaN  NaN  NaN  NaN
# ___mactrsmO  NaN  NaN  NaN  NaN  NaN  NaN
# ___mactrsmP  NaN  NaN  NaN  NaN  NaN  NaN
# ___mactrsmQ  NaN  NaN  NaN  NaN  NaN  NaN
#
# [421 rows x 6 columns]

# %%
# Iterate through the rows of the cal_params DataFrame
for cal_params_index, cal_params_row in cal_params.iterrows():
    # Iterate through the index of ostin
    for ostin_index in ostin.index:
        # Check if the string in the index of ostin contains the string in the index of cal_params
        if cal_params_index in ostin_index:
            # Append the row from cal_params to the corresponding index in ostin
            ostin.loc[ostin_index] = cal_params_row.values

# %%
ostin
# Out:
#                     1    2    3     4     5     6
# ___ttmpA     2.909494 -3.0  3.0  none  none  none
# ___ttmpB     2.909494 -3.0  3.0  none  none  none
# ___ttmpC     2.909494 -3.0  3.0  none  none  none
# ___ttmpD     2.909494 -3.0  3.0  none  none  none
# ___ttmpE     2.909494 -3.0  3.0  none  none  none
# ...               ...  ...  ...   ...   ...   ...
# ___mactrsmM       0.2  0.0  0.8  none  none  none
# ___mactrsmN       0.2  0.0  0.8  none  none  none
# ___mactrsmO       0.2  0.0  0.8  none  none  none
# ___mactrsmP       0.2  0.0  0.8  none  none  none
# ___mactrsmQ       0.2  0.0  0.8  none  none  none
#
# [421 rows x 6 columns]

# %%
# replace initial values with random
ostin[1]= 'random'

# %%
ostin
# Out:
#                   1    2    3     4     5     6
# ___ttmpA     random -3.0  3.0  none  none  none
# ___ttmpB     random -3.0  3.0  none  none  none
# ___ttmpC     random -3.0  3.0  none  none  none
# ___ttmpD     random -3.0  3.0  none  none  none
# ___ttmpE     random -3.0  3.0  none  none  none
# ...             ...  ...  ...   ...   ...   ...
# ___mactrsmM  random  0.0  0.8  none  none  none
# ___mactrsmN  random  0.0  0.8  none  none  none
# ___mactrsmO  random  0.0  0.8  none  none  none
# ___mactrsmP  random  0.0  0.8  none  none  none
# ___mactrsmQ  random  0.0  0.8  none  none  none
#
# [421 rows x 6 columns]

# %%
# Custom header and footer strings
top_half = """#Basic Configuration for Ostrich Program

#Essential variables
ProgramType ParallelDDS
ModelExecutable ./kge_calibrate.py
ModelSubdir mod_
ObjectiveFunction GCOP
OstrichWarmStart no

#Template File Configuration
BeginFilePairs
data/par_paired.txt ; data/par.txt
EndFilePairs

BeginExtraFiles
EndExtraFiles

BeginExtraDirs
data
EndExtraDirs


BeginParams"""

# %%
bottom_half= """EndParams

#Output variables to analyze
BeginResponseVars
#name   filename            keyword         line    col     token
KGE ./average_kge.txt ; OST_NULL 0 1 ' '
EndResponseVars

BeginGCOP
CostFunction KGE
PenaltyFunction APM
EndGCOP

#DDS algorithm setup
BeginParallelDDSAlg
PerturbationValue 0.2
MaxIterations 50000
EndParallelDDSAlg
"""

# %%
ostin.to_csv('./test', header=False, sep=' ')

# %%
# Write the DataFrame to a text file with header and footer strings
with open('./ostIn.txt', 'w') as file:
    file.write(top_half + '\n')
    ostin.to_csv(file, header=False, sep=' ', line_terminator='\n')  # You can change the separator if needed
    file.write(bottom_half)
# Out:
# C:\Users\Paul Coderre\AppData\Local\Temp\ipykernel_6436\844005669.py:4: FutureWarning: the 'line_terminator'' keyword is deprecated, use 'lineterminator' instead.
#   ostin.to_csv(file, header=False, sep=' ', line_terminator='\n')  # You can change the separator if needed

# %%
# Save par DataFrame as a tab-separated text file
par.to_csv('./data/par_paired.txt', sep='\t',header=False)

# %%
# Save par DataFrame as a tab-separated text file
#old_par.to_csv('./data/par.txt', sep='\t',header=False)
