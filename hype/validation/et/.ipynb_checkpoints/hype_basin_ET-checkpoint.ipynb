# %%
import os
import pandas as pd
from glob import glob
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np

# %% [markdown]
# ### Inputs

# %%
# Read  hype ET
hype = pd.read_csv('../../model/model_versions/v_6/v_6_2/results/timeEVAP_DD.txt',delimiter='\t',index_col=0,skiprows=1)

# %%
# read modified shapefile
gdf = gpd.read_file('../../geospacial/shapefiles/modified_shapefiles/Modified_SMMcat.shp')

# %% [markdown]
# ### Read MODIS

# %%
# Directory containing CSV files
directory = "C:/Users/Paul Coderre/Documents/Thesis/Validation/hype_mean/MOD16A3GF.061"

# Initialize an empty dataframe to store the merged data
merged_df = pd.DataFrame()

# Get a list of all CSV files in the directory
csv_files = glob(os.path.join(directory, '*.csv'))

# %%
# Iterate through each CSV file in the directory
for file_name in csv_files[:]:  # Make a copy of the list to iterate over
    # Read the CSV file into a dataframe
    df = pd.read_csv(file_name, index_col=0)
    
    # Extract the index and column name from the file name
    index_name = os.path.splitext(os.path.basename(file_name))[0]
    
    # If merged_df is empty, directly assign df to it
    if merged_df is None:
        merged_df = df
    else:
        # Merge only the first column of df with merged_df based on the index
        merged_df[index_name] = df.iloc[:, 0]
    
    # Remove the processed file from the list
    csv_files.remove(file_name)

# %%
# Rename columns to year
new_columns = {}
for column in merged_df.columns:
    year = column.split('_')[-1]  # Extract year from column name
    new_columns[column] = int(year)  # Convert year to integer and assign as new column name
merged_df.rename(columns=new_columns, inplace=True)

# %%
# Sort DataFrame by column names (years)
merged_df = merged_df.sort_index(axis=1)

# %%
# Multiply every value in the DataFrame by 0.1
obs_scaled = merged_df * 0.1

# %%
# Extract two columns from GeoDataFrame to create a renaming key
renaming_key = gdf[['hru_nhm', 'seg_nhm']]

# %%
# Set 'nhm_id' as the index in renaming key DataFrame
renaming_key.set_index('hru_nhm', inplace=True)

# %%
# Rename index values in DataFrame using the renaming key
obs_scaled.index = obs_scaled.index.map(renaming_key['seg_nhm'])

# %%
# Convert index to integers
obs_scaled.index = obs_scaled.index.astype(int)

# Sort index in ascending order
obs_scaled = obs_scaled.sort_index()

# %%
obs_scaled = obs_scaled.transpose()

# %%
# Remove index title
obs_scaled.index.name = None

# %%
# Convert column headers to integers
obs_scaled.columns = obs_scaled.columns.astype(int)

# %%
# Sort columns in ascending order
obs_scaled = obs_scaled.sort_index(axis=1)

# %%
obs_scaled
# Out:
# hru_nhm       58183       58184       58185       58186       58188  \
# 2001     332.064111  264.741162  250.659985  273.547168  269.762622
# 2002     434.820459  391.405786  376.792700  384.733887  372.000098
# 2003     400.433887  341.091113  323.080591  348.669873  343.875806
# 2004     411.697070  386.045654  351.604346  373.451855  364.999194
# 2005     427.042822  403.548657  378.779004  383.682251  379.551611
# 2006     439.619775  420.011182  386.341748  400.543799  406.921533
# 2007     399.799878  356.901782  338.789038  352.047778  347.781079
# 2008     447.006982  409.840186  376.940698  382.070386  378.788843
# 2009     404.834424  375.348169  354.553882  360.450659  345.471509
# 2009     324.624805  287.054077  292.451050  291.843555  272.714185
# 2010     329.033545  302.500024  318.799658  315.803491  299.333350
# 2011     348.650757  322.954199  331.033960  323.117969  331.694995
# 2012     354.218066  302.344775  305.829907  284.793945  296.779834
# 2013     373.066870  332.220972  338.262183  319.257666  314.521606
# 2014     403.303247  337.392627  333.431299  316.545044  320.656665
# 2015     384.932056  319.106323  320.332617  284.327148  322.034375
#
# [15 rows x 473 columns]

# %% [markdown]
# ### Analysis

# %%
# Convert index to datetime format
hype.index = pd.to_datetime(hype.index)

# Trim dataframe to include only data from 2001 to 2015
hype = hype['2001':'2015']

# %%
# Convert index to datetime
hype.index = pd.to_datetime(hype.index)

# Resample to yearly by summing
hype = hype.resample('Y').sum()
# Out:
# C:\Users\Paul Coderre\AppData\Local\Temp\ipykernel_42760\2753179895.py:5: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   hype = hype.resample('Y').sum()

# %%
# Convert index to datetime
hype.index = pd.to_datetime(hype.index)

# Extract year from datetime index and convert it to integer
hype.index = hype.index.year.astype(int)

# %%
# Remove index title
hype.index.name = None

# %%
# Convert column headers to integers
hype.columns = hype.columns.astype(int)

# %%
# Sort columns in ascending order
hype = hype.sort_index(axis=1)

# %%
hype
# Out:
#         58183    58184    58185    58186    58188    58189    58192    58193  \
# 2001  162.293  181.988  167.438  171.498  162.806  177.310  182.431  180.583
# 2002  330.863  353.459  280.850  322.046  281.760  342.720  334.082  302.092
# 2003  225.025  240.786  211.850  223.482  201.873  228.631  221.663  212.750
# 2004  284.365  302.662  259.991  283.712  259.668  300.035  279.307  274.494
# 2005  297.423  316.449  258.053  294.258  265.856  324.541  317.152  303.953
# 2006  214.777  234.303  202.866  220.470  203.302  231.399  230.594  218.061
# 2007  216.879  224.995  197.241  215.230  200.337  233.409  237.769  218.079
# 2008  292.885  309.309  269.244  288.080  264.472  295.083  289.033  279.278
# 2009  257.298  279.267  242.217  258.868  235.938  260.345  254.998  247.187
# 2010  312.047  334.651  277.276  311.796  279.807  346.000  327.777  317.535
# 2011  264.575  288.944  238.332  265.883  238.463  282.448  262.661  257.953
# 2012  266.592  275.564  232.540  260.885  245.032  300.695  297.651  288.344
# 2013  272.783  291.644  253.322  272.825  251.110  290.197  289.341  271.785
# 2014  281.881  300.690  251.363  280.224  253.862  294.103  283.502  272.650
# 2015  230.295  238.915  218.622  234.572  226.387  260.535  249.924  253.279
#
#         58194    58197  ...    58666    58667    58668    58669    58670  \
# 2001  197.783  181.242  ...  248.131  229.464  248.705  234.946  235.653
# 2002  327.805  285.888  ...  476.994  429.223  508.788  486.129  475.626
# 2003  224.701  202.199  ...  325.139  328.285  354.305  328.907  330.237
# 2004  290.213  269.824  ...  431.703  469.424  443.001  472.697  474.783
# 2005  346.190  317.374  ...  342.395  276.375  342.048  325.943  320.442
# 2006  239.393  218.453  ...  259.845  274.773  256.464  240.075  249.456
# 2007  247.144  232.267  ...  272.107  265.543  291.117  278.007  276.577
# Convert difference Series to a DataFrame
mean_annual_difference_df = pd.DataFrame(mean_annual_difference, columns=['Mean'])

# %%
mean_annual_difference_df.max()
# Out:
# Mean    137.402392
# dtype: float64

# %%
mean_annual_difference_df.min()
# Out:
# Mean   -1974.464062
# dtype: float64

# %%
# Find the index of the minimum value
min_index=mean_annual_difference_df.idxmin()
min_index
# Out:
# Mean    58651
# dtype: int32

# %%
mean_annual_difference_df.mean()
# Out:
# Mean    14.244459
# dtype: float64

# %%
mean_annual_difference_df.median()
# Out:
# Mean    60.814
# dtype: float64

# %%
# Calculate Q1, Q3, and IQR
Q1 = mean_annual_difference_df['Mean'].quantile(0.25)
Q3 = mean_annual_difference_df['Mean'].quantile(0.75)
IQR = Q3 - Q1

# Calculate lower and upper bounds for outliers
lower_bound = Q1 - 6 * IQR
upper_bound = Q3 + 6 * IQR

# Find outliers
outliers = mean_annual_difference_df[(mean_annual_difference_df['Mean'] < lower_bound) | (mean_annual_difference_df['Mean'] > upper_bound)]

print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)
print('Max outlier:', outliers.max())
print('Min outlier:', outliers.min())
print("Number of outliers:", outliers.shape[0])
print("Outliers:")
print(outliers)
# Out:
# Lower Bound: -344.4050587239572
# Upper Bound: 463.16749947916543
# Max outlier: Mean   -426.005659
# dtype: float64
# Min outlier: Mean   -1974.464062
# dtype: float64
# Number of outliers: 13
# Outliers:
#               Mean
# 58194  -426.005659
# 58212  -584.711383
# 58213 -1771.434451
# 58214  -676.048964
# 58219  -535.935637
# 58223  -430.401812
# 58265 -1267.242150
# 58284  -852.425628
# 58429  -888.684073
# 58444  -673.352484
# 58453  -851.338364
# 58505 -1320.505281
# 58651 -1974.464062

# %%
# Replace outliers with NaN
mean_annual_difference_df.loc[(mean_annual_difference_df['Mean'] < lower_bound) | (mean_annual_difference_df['Mean'] > upper_bound), 'Mean'] = np.nan

# %% [markdown]
# ### Plot heatmap

# %%
# Merge column_means_df onto gdf by the index in column_means_df and seg_nhm column in gdf
merged_gdf = gdf.merge(mean_annual_difference_df, left_on='seg_nhm', right_index=True)

# %%
nan_color = 'black'  

# Plot a heatmap of the 'Mean' column with adjusted figure size
ax = merged_gdf.plot(column='Mean', cmap='viridis', legend=True, figsize=(18, 8),missing_kwds={'color': nan_color})

# Add title to the plot
ax.set_title('Mean Difference Between Modelled and Observed Annual Actual ET')

# Get the color bar instance
cbar = ax.get_figure().get_axes()[1]

# Add units to the color bar
cbar.set_ylabel('mm / year')

# Manually draw a black box with text to represent NaN values
ax.text(0.5, -0.175, 'Black= Outliers (14) Between -367.36 and -1981.14 mm/year', transform=ax.transAxes, color='white', fontsize=14,
        bbox=dict(facecolor='black', alpha=1, boxstyle='round,pad=0.3'))

# Add units for lat and lon (assuming you want to annotate the axes)
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')

# Save the plot as PNG to a specific location
plt.savefig('./hypev6_2_et.png')

# Show the plot
plt.show()
