# %%
import pandas as pd

# %% [markdown]
# ### Define Functions

# %%
# Define a function to keep the first and third occurrence of each index item
def keep_first_and_third(group):
    # Keep the first and third rows of each group
    return group.iloc[[0, 2]] if len(group) >= 3 else group

# %%
# Define a function to assign 'Milk' and 'StM'
def assign_region(group):
    # Create a new column 'region' with default value 'StM'
    group['region'] = 'StM'
    # Set 'Milk' for the first appearance
    group.iloc[0, group.columns.get_loc('region')] = 'Milk'
    return group

# %%
def write_par_table(par: str,
                    reg_par: str,
                    reg_par_key: str,
                    cal_params: str,
                    lu_classes: str,
                    st_classes: str) -> pd.DataFrame:
    
    """ This function writes a table contaning all HYPE parameters based on the outputs:
    
    par: Path to the par.txt file in HYPE
    reg_par: Path to the reg_par.txt file in HYPE
    reg_par_key: Path to the key containing regionalized parameters and their regression values
    cal_params: Path to the dataframe of parameters being calibrated
    lu_classes: Path to the file containing the land use classes and what they represent
    st_classes: Path to the file containing the soil type classes and what they represent """


    # Read the file into a DataFrame, ignoring lines starting with '#'
    par = pd.read_csv(par, comment='!', delimiter='\t', header= None, index_col=0)

    # read regional parameters
    reg_par= pd.read_csv(reg_par, delim_whitespace=True, skiprows=1, header= None, index_col= 0)

    # read regional parameter regression key
    reg_par_key= pd.read_excel(reg_par_key, index_col=0)

    # read cal params
    cal_params= pd.read_csv(cal_params, delimiter='\t',header= None,index_col=0)

    # read land use classes
    lu_classes= pd.read_excel(lu_classes, sheet_name='Land Use',index_col=0)

    # read soil type classes
    st_classes= pd.read_excel(st_classes, sheet_name='Soil Type',index_col=0)
    
    # Format regionalized parameters
    
    # Apply the function to each group
    filtered_reg_par = reg_par.groupby(level=0).apply(keep_first_and_third).reset_index(level=0, drop=True)

    # Apply the function to each group
    filtered_reg_par = filtered_reg_par.groupby(0, group_keys=False).apply(assign_region)

    # Merge the DataFrames on the index
    merged_reg_par = filtered_reg_par.join(reg_par_key)

    # Multiply the values in the first column by the 'Regression' values
    merged_reg_par['Value'] = merged_reg_par[1] * merged_reg_par['Regression']

    # Drop the 'Regression' column if not needed
    merged_reg_par = merged_reg_par.drop(columns=['Regression', 1])

    # Pivot the DataFrame
    pivot_reg_par = merged_reg_par.reset_index().pivot(index='index', columns='region', values='Value')

    # Rename index to 'Parameter'
    pivot_reg_par.index.name = 'Parameter'

    # Format parameter file
    
    # Convert index of cal_params to string
    cal_params.index = cal_params.index.astype(str)

    # Change column names in cal_params to integers
    cal_params.columns = range(cal_params.shape[1])

    # Convert index of par to string
    par.index = par.index.astype(str)

    # Convert column headers of 'par' to integers
    par.columns = par.columns.astype(int)

    # Convert index of lu_classes to int
    lu_classes.index = lu_classes.index.astype(int)

    # Convert index of st_classes to int
    st_classes.index = st_classes.index.astype(int)
    
    # Create a land use mapping dictionary
    lu_mapping = dict(zip(lu_classes.index, lu_classes.iloc[:, 0]))

    # Create a soil type mapping dictionary
    st_mapping = dict(zip(st_classes.index, st_classes.iloc[:, 0]))
    
    lu_indices = par.index.intersection(cal_params.index)
    # Filter rows where the 6th column of 'cal_params' has the value 'Land Use'
    land_use = par.loc[
        lu_indices[cal_params.loc[lu_indices].iloc[:, 6] == 'Land Use']
    ]

    # Update the DataFrame's columns using the mapping dictionary
    land_use.columns = [lu_mapping.get(col, col) for col in land_use.columns]

    # Set the name of the index
    land_use = land_use.rename_axis('Parameter')
    
    st_indices = par.index.intersection(cal_params.index)
    
    # Filter rows where the 6th column of 'cal_params' has the value 'Land Use'
    soil_type = par.loc[
        st_indices[cal_params.loc[st_indices].iloc[:, 6] == 'Soil Type']
    ]

    # Update the DataFrame's columns using the mapping dictionary
    soil_type.columns = [st_mapping.get(col, col) for col in soil_type.columns]

    # Set the name of the index
    soil_type = soil_type.rename_axis('Parameter')

    # Drop any column that contains NaN values
    soil_type = soil_type.dropna(axis=1)
    
    general_indices = par.index.intersection(cal_params.index)
    # Filter rows where the 6th column of 'cal_params' has the value 'Land Use'
    general = par.loc[
        general_indices[cal_params.loc[general_indices].iloc[:, 6] == 'General']
    ]

    # Set the name of the index
    general = general.rename_axis('Parameter')

    # Drop any column that contains NaN values
    general = general.dropna(axis=1)

    general.rename(columns={general.columns[0]: 'General'}, inplace=True)
    
    # Concatenate the DataFrames with different headers and indexes
    combined_par = pd.concat([land_use, soil_type, general, pivot_reg_par], keys=['Land Use', 'Soil Type', 'General', 'Regionalized General'])

    # Round values to 3 significant figures
    combined_par = combined_par.round(3)
    
    return combined_par

# %%
def filter_by_sensitivity(par: pd.DataFrame)-> pd.DataFrame:
    
    # List of keywords to filter the columns (most dominant lu/st)
    keywords = ['Temperate or sub-polar shrubland', 
                'Temperate or sub-polar grassland', 
                'Cropland', 
                '_Clay'] # this will keep only Clay and Clay loam, otherwise it keeps anything with clay in it
    
    # Creating a boolean mask for column selection based on keywords
    mask = par.columns.str.contains('|'.join(keywords), case=False)

    # Filtering the DataFrame to keep only the desired columns
    filtered_par= par.loc[:, mask]
    
    return filtered_par

# %%
def find_difference(par1: pd.DataFrame, par2: pd.DataFrame)-> pd.DataFrame:
    
    # Check if both DataFrames have the same index and columns
    if par1.index.equals(par2.index) and par1.columns.equals(par2.columns):
        # Subtract par2 from par1
        result = par1 - par2
        
        return result
    
    else:
        mismatch_info = []
        if not par1.index.equals(par2.index):
            mismatch_info.append(f"Indexes do not match: par1 index = {par1.index}, par2 index = {par2.index}")
        if not par1.columns.equals(par2.columns):
            mismatch_info.append(f"Headers do not match: par1 headers = {par1.columns}, par2 headers = {par2.columns}")
            
        return "\n".join(mismatch_info)

# %% [markdown]
# ### Inputs

# %%
# Define paths that apply to all parameter sets
# read regional parameter regression key
reg_par_key_path= '../../geospacial/misc/reg_par_key.xlsx'

# read cal params
cal_params_path= '../../calibration/cal_param.txt'

# read land use classes
lu_classes_path= '../../geospacial/misc/lu_st_classes.xlsx'

# read soil type classes
st_classes_path= '../../geospacial/misc/lu_st_classes.xlsx'

# %% [markdown]
# ### Analysis

# %%
# Define model specific parameter paths
par_path_nse= '../../model/seperate_cal/02_nse_combined/par.txt'

# read regional parameters
reg_par_path_nse= '../../model/seperate_cal/02_nse_combined/reg_par.txt'

# generate table
par_nse= write_par_table(par_path_nse, reg_par_path_nse, reg_par_key_path, 
                         cal_params_path, lu_classes_path, st_classes_path)

# %%
# Define model specific parameter paths
par_path_kge= '../../model/seperate_cal/01_kge_combined_model/par.txt'

# read regional parameters
reg_par_path_kge= '../../model/seperate_cal/01_kge_combined_model/reg_par.txt'

# generate table
par_kge= write_par_table(par_path_kge, reg_par_path_kge, reg_par_key_path, 
                         cal_params_path, lu_classes_path, st_classes_path)

# %%
# filter by most dominant lu and st
par_nse_filtered= filter_by_sensitivity(par_nse)
par_kge_filtered= filter_by_sensitivity(par_kge)

# %%
# find difference (par1-par2)
difference= find_difference(par_nse_filtered, par_kge_filtered)

# %%
par_kge_filtered
# Out:
#                                  04_Milk_Temperate or sub-polar shrubland  \
#                      Parameter
# Land Use             ttmp                                          -0.969
#                      cmlt                                           4.184
#                      kc3                                            0.731
#                      alb                                            0.464
#                      srrcs                                          0.050
# Soil Type            bfroznsoil                                       NaN
#                      bcosby                                           NaN
#                      rrcs1                                            NaN
#                      rrcs2                                            NaN
#                      srrate                                           NaN
#                      wcwp1                                            NaN
#                      wcwp2                                            NaN
#                      wcwp3                                            NaN
#                      wcfc1                                            NaN
#                      wcfc2                                            NaN
#                      wcfc3                                            NaN
#                      wcep1                                            NaN
#                      wcep2                                            NaN
#                      wcep3                                            NaN
#                      mperc1                                           NaN
#                      mperc2                                           NaN
#                      macrate                                          NaN
#                      mactrinf                                         NaN
#                      mactrsm                                          NaN
# General              wetrate                                          NaN
#                      wetexp                                           NaN
#                      iwetw0                                           NaN
# Regionalized General damp                                             NaN
#                      lp                                               NaN
#                      rivvel                                           NaN
#                      rrcs3                                            NaN
#
#                                  05_Milk_Temperate or sub-polar grassland  \
#                      Parameter
# Land Use             ttmp                                           1.849
#                      cmlt                                           2.271
#                      kc3                                            0.965
#                      alb                                            0.151
#                      srrcs                                          0.095
# Soil Type            bfroznsoil                                       NaN
#                      bcosby                                           NaN
#                      rrcs1                                            NaN
#                      rrcs2                                            NaN
#                      srrate                                           NaN
#                      wcwp1                                            NaN
#                      wcwp2                                            NaN
#                      wcwp3                                            NaN
#                      wcfc1                                            NaN
#                      wcfc2                                            NaN
#                      wcfc3                                            NaN
#                      wcep1                                            NaN
#                      wcep2                                            NaN
#                      wcep3                                            NaN
#                      mperc1                                           NaN
#                      mperc2                                           NaN
#                      macrate                                          NaN
#                      mactrinf                                         NaN
#                      mactrsm                                          NaN
# General              wetrate                                          NaN
#                      wetexp                                           NaN
#                      iwetw0                                           NaN
# Regionalized General damp                                             NaN
#                      lp                                               NaN
#                      rivvel                                           NaN
#                      rrcs3                                            NaN
#
#                                  09_Milk_Cropland  \
#                      Parameter
# Land Use             ttmp                  -0.624
#                      cmlt                   2.239
#                      kc3                    1.065
#                      alb                    0.381
#                      srrcs                  0.056
# Soil Type            bfroznsoil               NaN
#                      bcosby                   NaN
#                      rrcs1                    NaN
#                      rrcs2                    NaN
#                      srrate                   NaN
#                      wcwp1                    NaN
#                      wcwp2                    NaN
#                      wcwp3                    NaN
#                      wcfc1                    NaN
#                      wcfc2                    NaN
#                      wcfc3                    NaN
#                      wcep1                    NaN
#                      wcep2                    NaN
#                      wcep3                    NaN
#                      mperc1                   NaN
#                      mperc2                   NaN
#                      macrate                  NaN
#                      mactrinf                 NaN
#                      mactrsm                  NaN
# General              wetrate                  NaN
#                      wetexp                   NaN
#                      iwetw0                   NaN
# Regionalized General damp                     NaN
#                      lp                       NaN
#                      rivvel                   NaN
#                      rrcs3                    NaN
#
#                                  16_StM_Temperate or sub-polar shrubland  \
#                      Parameter
# Land Use             ttmp                                         -0.351
#                      cmlt                                          9.664
#                      kc3                                           0.400
#                      alb                                           0.398
#                      srrcs                                         0.194
# Soil Type            bfroznsoil                                      NaN
#                      bcosby                                          NaN
#                      rrcs1                                           NaN
#                      rrcs2                                           NaN
#                      srrate                                          NaN
#                      wcwp1                                           NaN
#                      wcwp2                                           NaN
#                      wcwp3                                           NaN
#                      wcfc1                                           NaN
#                      wcfc2                                           NaN
#                      wcfc3                                           NaN
#                      wcep1                                           NaN
#                      wcep2                                           NaN
#                      wcep3                                           NaN
#                      mperc1                                          NaN
#                      mperc2                                          NaN
#                      macrate                                         NaN
#                      mactrinf                                        NaN
#                      mactrsm                                         NaN
# General              wetrate                                         NaN
#                      wetexp                                          NaN
#                      iwetw0                                          NaN
# Regionalized General damp                                            NaN
#                      lp                                              NaN
#                      rivvel                                          NaN
#                      rrcs3                                           NaN
#
#                                  17_StM_Temperate or sub-polar grassland  \
#                      Parameter
# Land Use             ttmp                                          0.625
#                      cmlt                                          1.037
#                      kc3                                           0.401
#                      alb                                           0.114
#                      srrcs                                         0.200
# Soil Type            bfroznsoil                                      NaN
#                      bcosby                                          NaN
#                      rrcs1                                           NaN
#                      rrcs2                                           NaN
#                      srrate                                          NaN
#                      wcwp1                                           NaN
#                      wcwp2                                           NaN
#                      wcwp3                                           NaN
#                      wcfc1                                           NaN
#                      wcfc2                                           NaN
#                      wcfc3                                           NaN
#                      wcep1                                           NaN
#                      wcep2                                           NaN
#                      wcep3                                           NaN
#                      mperc1                                          NaN
#                      mperc2                                          NaN
#                      macrate                                         NaN
#                      mactrinf                                        NaN
#                      mactrsm                                         NaN
# General              wetrate                                         NaN
#                      wetexp                                          NaN
#                      iwetw0                                          NaN
# Regionalized General damp                                            NaN
#                      lp                                              NaN
#                      rivvel                                          NaN
#                      rrcs3                                           NaN
#
#                                  19_StM_Cropland  02_Milk_Clay  \
#                      Parameter
# Land Use             ttmp                 -2.652           NaN
#                      cmlt                  8.778           NaN
#                      kc3                   0.403           NaN
#                      alb                   0.146           NaN
#                      srrcs                 0.196           NaN
# Soil Type            bfroznsoil              NaN         4.231
#                      bcosby                  NaN         5.443
#                      rrcs1                   NaN         0.067
#                      rrcs2                   NaN         0.189
#                      srrate                  NaN         0.136
#                      wcwp1                   NaN         0.077
#                      wcwp2                   NaN         0.040
#                      wcwp3                   NaN         0.033
#                      wcfc1                   NaN         0.366
#                      wcfc2                   NaN         0.209
#                      wcfc3                   NaN         0.114
#                      wcep1                   NaN         0.235
#                      wcep2                   NaN         0.625
#                      wcep3                   NaN         0.382
#                      mperc1                  NaN        95.822
#                      mperc2                  NaN       108.646
#                      macrate                 NaN         0.256
#                      mactrinf                NaN        32.913
#                      mactrsm                 NaN         0.605
# General              wetrate                 NaN           NaN
#                      wetexp                  NaN           NaN
#                      iwetw0                  NaN           NaN
# Regionalized General damp                    NaN           NaN
#                      lp                      NaN           NaN
#                      rivvel                  NaN           NaN
#                      rrcs3                   NaN           NaN
#
#                                  03_Milk_Clay loam  11_StM_Clay  \
#                      Parameter
# Land Use             ttmp                      NaN          NaN
#                      cmlt                      NaN          NaN
#                      kc3                       NaN          NaN
#                      alb                       NaN          NaN
#                      srrcs                     NaN          NaN
# Soil Type            bfroznsoil              4.178        3.731
#                      bcosby                  7.860        3.472
#                      rrcs1                   0.237        0.252
#                      rrcs2                   0.013        0.067
#                      srrate                  0.256        0.134
#                      wcwp1                   0.275        0.498
#                      wcwp2                   0.440        0.296
#                      wcwp3                   0.076        0.416
#                      wcfc1                   0.488        0.491
#                      wcfc2                   0.468        0.128
#                      wcfc3                   0.233        0.184
#                      wcep1                   0.470        0.184
#                      wcep2                   0.380        0.018
#                      wcep3                   0.400        0.235
#                      mperc1                 46.164       17.267
#                      mperc2                  5.840       70.390
#                      macrate                 0.444        0.359
#                      mactrinf               79.900       22.687
#                      mactrsm                 0.461        0.501
# General              wetrate                   NaN          NaN
#                      wetexp                    NaN          NaN
#                      iwetw0                    NaN          NaN
# Regionalized General damp                      NaN          NaN
#                      lp                        NaN          NaN
#                      rivvel                    NaN          NaN
#                      rrcs3                     NaN          NaN
#
#                                  12_StM_Clay loam
#                      Parameter
# Land Use             ttmp                     NaN
#                      cmlt                     NaN
#                      kc3                      NaN
#                      alb                      NaN
#                      srrcs                    NaN
# Soil Type            bfroznsoil             3.368
#                      bcosby                15.743
#                      rrcs1                  0.104
#                      rrcs2                  0.002
#                      srrate                 0.103
#                      wcwp1                  0.338
#                      wcwp2                  0.393
#                      wcwp3                  0.042
#                      wcfc1                  0.059
#                      wcfc2                  0.050
#                      wcfc3                  0.434
#                      wcep1                  0.889
#                      wcep2                  0.734
#                      wcep3                  0.810
#                      mperc1               116.239
#                      mperc2                80.414
#                      macrate                0.405
#                      mactrinf              55.304
#                      mactrsm                0.742
# General              wetrate                  NaN
#                      wetexp                   NaN
#                      iwetw0                   NaN
# Regionalized General damp                     NaN
#                      lp                       NaN
#                      rivvel                   NaN
#                      rrcs3                    NaN

# %%
par_nse_filtered
# Out:
#                                  04_Milk_Temperate or sub-polar shrubland  \
#                      Parameter
# Land Use             ttmp                                          -1.269
#                      cmlt                                           5.285
#                      kc3                                            0.707
#                      alb                                            0.144
#                      srrcs                                          0.165
# Soil Type            bfroznsoil                                       NaN
#                      bcosby                                           NaN
#                      rrcs1                                            NaN
#                      rrcs2                                            NaN
#                      srrate                                           NaN
#                      wcwp1                                            NaN
#                      wcwp2                                            NaN
#                      wcwp3                                            NaN
#                      wcfc1                                            NaN
#                      wcfc2                                            NaN
#                      wcfc3                                            NaN
#                      wcep1                                            NaN
#                      wcep2                                            NaN
#                      wcep3                                            NaN
#                      mperc1                                           NaN
#                      mperc2                                           NaN
#                      macrate                                          NaN
#                      mactrinf                                         NaN
#                      mactrsm                                          NaN
# General              wetrate                                          NaN
#                      wetexp                                           NaN
#                      iwetw0                                           NaN
# Regionalized General damp                                             NaN
#                      lp                                               NaN
#                      rivvel                                           NaN
#                      rrcs3                                            NaN
#
#                                  05_Milk_Temperate or sub-polar grassland  \
#                      Parameter
# Land Use             ttmp                                          -1.232
#                      cmlt                                           1.167
#                      kc3                                            0.993
#                      alb                                            0.207
#                      srrcs                                          0.092
# Soil Type            bfroznsoil                                       NaN
#                      bcosby                                           NaN
#                      rrcs1                                            NaN
#                      rrcs2                                            NaN
#                      srrate                                           NaN
#                      wcwp1                                            NaN
#                      wcwp2                                            NaN
#                      wcwp3                                            NaN
#                      wcfc1                                            NaN
#                      wcfc2                                            NaN
#                      wcfc3                                            NaN
#                      wcep1                                            NaN
#                      wcep2                                            NaN
#                      wcep3                                            NaN
#                      mperc1                                           NaN
#                      mperc2                                           NaN
#                      macrate                                          NaN
#                      mactrinf                                         NaN
#                      mactrsm                                          NaN
# General              wetrate                                          NaN
#                      wetexp                                           NaN
#                      iwetw0                                           NaN
# Regionalized General damp                                             NaN
#                      lp                                               NaN
#                      rivvel                                           NaN
#                      rrcs3                                            NaN
#
#                                  09_Milk_Cropland  \
#                      Parameter
# Land Use             ttmp                   2.885
#                      cmlt                   5.601
#                      kc3                    1.174
#                      alb                    0.157
#                      srrcs                  0.017
# Soil Type            bfroznsoil               NaN
#                      bcosby                   NaN
#                      rrcs1                    NaN
#                      rrcs2                    NaN
#                      srrate                   NaN
#                      wcwp1                    NaN
#                      wcwp2                    NaN
#                      wcwp3                    NaN
#                      wcfc1                    NaN
#                      wcfc2                    NaN
#                      wcfc3                    NaN
#                      wcep1                    NaN
#                      wcep2                    NaN
#                      wcep3                    NaN
#                      mperc1                   NaN
#                      mperc2                   NaN
#                      macrate                  NaN
#                      mactrinf                 NaN
#                      mactrsm                  NaN
# General              wetrate                  NaN
#                      wetexp                   NaN
#                      iwetw0                   NaN
# Regionalized General damp                     NaN
#                      lp                       NaN
#                      rivvel                   NaN
#                      rrcs3                    NaN
#
#                                  16_StM_Temperate or sub-polar shrubland  \
#                      Parameter
# Land Use             ttmp                                         -1.054
#                      cmlt                                          4.169
#                      kc3                                           0.401
#                      alb                                           0.376
#                      srrcs                                         0.164
# Soil Type            bfroznsoil                                      NaN
#                      bcosby                                          NaN
#                      rrcs1                                           NaN
#                      rrcs2                                           NaN
#                      srrate                                          NaN
#                      wcwp1                                           NaN
#                      wcwp2                                           NaN
#                      wcwp3                                           NaN
#                      wcfc1                                           NaN
#                      wcfc2                                           NaN
#                      wcfc3                                           NaN
#                      wcep1                                           NaN
#                      wcep2                                           NaN
#                      wcep3                                           NaN
#                      mperc1                                          NaN
#                      mperc2                                          NaN
#                      macrate                                         NaN
#                      mactrinf                                        NaN
#                      mactrsm                                         NaN
# General              wetrate                                         NaN
#                      wetexp                                          NaN
#                      iwetw0                                          NaN
# Regionalized General damp                                            NaN
#                      lp                                              NaN
#                      rivvel                                          NaN
#                      rrcs3                                           NaN
#
#                                  17_StM_Temperate or sub-polar grassland  \
#                      Parameter
# Land Use             ttmp                                          2.936
#                      cmlt                                          1.247
#                      kc3                                           0.402
#                      alb                                           0.325
#                      srrcs                                         0.100
# Soil Type            bfroznsoil                                      NaN
#                      bcosby                                          NaN
#                      rrcs1                                           NaN
#                      rrcs2                                           NaN
#                      srrate                                          NaN
#                      wcwp1                                           NaN
#                      wcwp2                                           NaN
#                      wcwp3                                           NaN
#                      wcfc1                                           NaN
#                      wcfc2                                           NaN
#                      wcfc3                                           NaN
#                      wcep1                                           NaN
#                      wcep2                                           NaN
#                      wcep3                                           NaN
#                      mperc1                                          NaN
#                      mperc2                                          NaN
#                      macrate                                         NaN
#                      mactrinf                                        NaN
#                      mactrsm                                         NaN
# General              wetrate                                         NaN
#                      wetexp                                          NaN
#                      iwetw0                                          NaN
# Regionalized General damp                                            NaN
#                      lp                                              NaN
#                      rivvel                                          NaN
#                      rrcs3                                           NaN
#
#                                  19_StM_Cropland  02_Milk_Clay  \
#                      Parameter
# Land Use             ttmp                 -2.655           NaN
#                      cmlt                  8.596           NaN
#                      kc3                   1.272           NaN
#                      alb                   0.444           NaN
#                      srrcs                 0.162           NaN
# Soil Type            bfroznsoil              NaN         1.145
#                      bcosby                  NaN         4.186
#                      rrcs1                   NaN         0.430
#                      rrcs2                   NaN         0.038
#                      srrate                  NaN         0.306
#                      wcwp1                   NaN         0.059
#                      wcwp2                   NaN         0.404
#                      wcwp3                   NaN         0.286
#                      wcfc1                   NaN         0.354
#                      wcfc2                   NaN         0.175
#                      wcfc3                   NaN         0.475
#                      wcep1                   NaN         0.116
#                      wcep2                   NaN         0.847
#                      wcep3                   NaN         0.743
#                      mperc1                  NaN        56.170
#                      mperc2                  NaN        97.920
#                      macrate                 NaN         0.166
#                      mactrinf                NaN        79.281
#                      mactrsm                 NaN         0.444
# General              wetrate                 NaN           NaN
#                      wetexp                  NaN           NaN
#                      iwetw0                  NaN           NaN
# Regionalized General damp                    NaN           NaN
#                      lp                      NaN           NaN
#                      rivvel                  NaN           NaN
#                      rrcs3                   NaN           NaN
#
#                                  03_Milk_Clay loam  11_StM_Clay  \
#                      Parameter
# Land Use             ttmp                      NaN          NaN
#                      cmlt                      NaN          NaN
#                      kc3                       NaN          NaN
#                      alb                       NaN          NaN
#                      srrcs                     NaN          NaN
# Soil Type            bfroznsoil              1.276        1.018
#                      bcosby                  4.693       15.974
#                      rrcs1                   0.354        0.089
#                      rrcs2                   0.030        0.052
#                      srrate                  0.240        0.315
#                      wcwp1                   0.036        0.312
#                      wcwp2                   0.412        0.082
#                      wcwp3                   0.079        0.316
#                      wcfc1                   0.409        0.068
#                      wcfc2                   0.392        0.301
#                      wcfc3                   0.472        0.096
#                      wcep1                   0.708        0.484
#                      wcep2                   0.546        0.295
#                      wcep3                   0.578        0.638
#                      mperc1                112.189       20.886
#                      mperc2                  9.552       15.508
#                      macrate                 0.325        0.219
#                      mactrinf               51.572       69.293
#                      mactrsm                 0.470        0.666
# General              wetrate                   NaN          NaN
#                      wetexp                    NaN          NaN
#                      iwetw0                    NaN          NaN
# Regionalized General damp                      NaN          NaN
#                      lp                        NaN          NaN
#                      rivvel                    NaN          NaN
#                      rrcs3                     NaN          NaN
#
#                                  12_StM_Clay loam
#                      Parameter
# Land Use             ttmp                     NaN
#                      cmlt                     NaN
#                      kc3                      NaN
#                      alb                      NaN
#                      srrcs                    NaN
# Soil Type            bfroznsoil             1.256
#                      bcosby                13.833
#                      rrcs1                  0.598
#                      rrcs2                  0.002
#                      srrate                 0.435
#                      wcwp1                  0.414
#                      wcwp2                  0.235
#                      wcwp3                  0.409
#                      wcfc1                  0.129
#                      wcfc2                  0.056
#                      wcfc3                  0.057
#                      wcep1                  0.013
#                      wcep2                  0.055
#                      wcep3                  0.710
#                      mperc1                87.186
#                      mperc2                35.027
#                      macrate                0.004
#                      mactrinf              78.150
#                      mactrsm                0.137
# General              wetrate                  NaN
#                      wetexp                   NaN
#                      iwetw0                   NaN
# Regionalized General damp                     NaN
#                      lp                       NaN
#                      rivvel                   NaN
#                      rrcs3                    NaN

# %%
difference
# Out:
#                                  04_Milk_Temperate or sub-polar shrubland  \
#                      Parameter
# Land Use             ttmp                                          -0.300
#                      cmlt                                           1.101
#                      kc3                                           -0.024
#                      alb                                           -0.320
#                      srrcs                                          0.115
# Soil Type            bfroznsoil                                       NaN
#                      bcosby                                           NaN
#                      rrcs1                                            NaN
#                      rrcs2                                            NaN
#                      srrate                                           NaN
#                      wcwp1                                            NaN
#                      wcwp2                                            NaN
#                      wcwp3                                            NaN
#                      wcfc1                                            NaN
#                      wcfc2                                            NaN
#                      wcfc3                                            NaN
#                      wcep1                                            NaN
#                      wcep2                                            NaN
#                      wcep3                                            NaN
#                      mperc1                                           NaN
#                      mperc2                                           NaN
#                      macrate                                          NaN
#                      mactrinf                                         NaN
#                      mactrsm                                          NaN
# General              wetrate                                          NaN
#                      wetexp                                           NaN
#                      iwetw0                                           NaN
# Regionalized General damp                                             NaN
#                      lp                                               NaN
#                      rivvel                                           NaN
#                      rrcs3                                            NaN
#
#                                  05_Milk_Temperate or sub-polar grassland  \
#                      Parameter
# Land Use             ttmp                                          -3.081
#                      cmlt                                          -1.104
#                      kc3                                            0.028
#                      alb                                            0.056
#                      srrcs                                         -0.003
# Soil Type            bfroznsoil                                       NaN
#                      bcosby                                           NaN
#                      rrcs1                                            NaN
#                      rrcs2                                            NaN
#                      srrate                                           NaN
#                      wcwp1                                            NaN
#                      wcwp2                                            NaN
#                      wcwp3                                            NaN
#                      wcfc1                                            NaN
#                      wcfc2                                            NaN
#                      wcfc3                                            NaN
#                      wcep1                                            NaN
#                      wcep2                                            NaN
#                      wcep3                                            NaN
#                      mperc1                                           NaN
#                      mperc2                                           NaN
#                      macrate                                          NaN
#                      mactrinf                                         NaN
#                      mactrsm                                          NaN
# General              wetrate                                          NaN
#                      wetexp                                           NaN
#                      iwetw0                                           NaN
# Regionalized General damp                                             NaN
#                      lp                                               NaN
#                      rivvel                                           NaN
#                      rrcs3                                            NaN
#
#                                  09_Milk_Cropland  \
#                      Parameter
# Land Use             ttmp                   3.509
#                      cmlt                   3.362
#                      kc3                    0.109
#                      alb                   -0.224
#                      srrcs                 -0.039
# Soil Type            bfroznsoil               NaN
#                      bcosby                   NaN
#                      rrcs1                    NaN
#                      rrcs2                    NaN
#                      srrate                   NaN
#                      wcwp1                    NaN
#                      wcwp2                    NaN
#                      wcwp3                    NaN
#                      wcfc1                    NaN
#                      wcfc2                    NaN
#                      wcfc3                    NaN
#                      wcep1                    NaN
#                      wcep2                    NaN
#                      wcep3                    NaN
#                      mperc1                   NaN
#                      mperc2                   NaN
#                      macrate                  NaN
#                      mactrinf                 NaN
#                      mactrsm                  NaN
# General              wetrate                  NaN
#                      wetexp                   NaN
#                      iwetw0                   NaN
# Regionalized General damp                     NaN
#                      lp                       NaN
#                      rivvel                   NaN
#                      rrcs3                    NaN
#
#                                  16_StM_Temperate or sub-polar shrubland  \
#                      Parameter
# Land Use             ttmp                                         -0.703
#                      cmlt                                         -5.495
#                      kc3                                           0.001
#                      alb                                          -0.022
#                      srrcs                                        -0.030
# Soil Type            bfroznsoil                                      NaN
#                      bcosby                                          NaN
#                      rrcs1                                           NaN
#                      rrcs2                                           NaN
#                      srrate                                          NaN
#                      wcwp1                                           NaN
#                      wcwp2                                           NaN
#                      wcwp3                                           NaN
#                      wcfc1                                           NaN
#                      wcfc2                                           NaN
#                      wcfc3                                           NaN
#                      wcep1                                           NaN
#                      wcep2                                           NaN
#                      wcep3                                           NaN
#                      mperc1                                          NaN
#                      mperc2                                          NaN
#                      macrate                                         NaN
#                      mactrinf                                        NaN
#                      mactrsm                                         NaN
# General              wetrate                                         NaN
#                      wetexp                                          NaN
#                      iwetw0                                          NaN
# Regionalized General damp                                            NaN
#                      lp                                              NaN
#                      rivvel                                          NaN
#                      rrcs3                                           NaN
#
#                                  17_StM_Temperate or sub-polar grassland  \
#                      Parameter
# Land Use             ttmp                                          2.311
#                      cmlt                                          0.210
#                      kc3                                           0.001
#                      alb                                           0.211
#                      srrcs                                        -0.100
# Soil Type            bfroznsoil                                      NaN
#                      bcosby                                          NaN
#                      rrcs1                                           NaN
#                      rrcs2                                           NaN
#                      srrate                                          NaN
#                      wcwp1                                           NaN
#                      wcwp2                                           NaN
#                      wcwp3                                           NaN
#                      wcfc1                                           NaN
#                      wcfc2                                           NaN
#                      wcfc3                                           NaN
#                      wcep1                                           NaN
#                      wcep2                                           NaN
#                      wcep3                                           NaN
#                      mperc1                                          NaN
#                      mperc2                                          NaN
#                      macrate                                         NaN
#                      mactrinf                                        NaN
#                      mactrsm                                         NaN
# General              wetrate                                         NaN
#                      wetexp                                          NaN
#                      iwetw0                                          NaN
# Regionalized General damp                                            NaN
#                      lp                                              NaN
#                      rivvel                                          NaN
#                      rrcs3                                           NaN
#
#                                  19_StM_Cropland  02_Milk_Clay  \
#                      Parameter
# Land Use             ttmp                 -0.003           NaN
#                      cmlt                 -0.182           NaN
#                      kc3                   0.869           NaN
#                      alb                   0.298           NaN
#                      srrcs                -0.034           NaN
# Soil Type            bfroznsoil              NaN        -3.086
#                      bcosby                  NaN        -1.257
#                      rrcs1                   NaN         0.363
#                      rrcs2                   NaN        -0.151
#                      srrate                  NaN         0.170
#                      wcwp1                   NaN        -0.018
#                      wcwp2                   NaN         0.364
#                      wcwp3                   NaN         0.253
#                      wcfc1                   NaN        -0.012
#                      wcfc2                   NaN        -0.034
#                      wcfc3                   NaN         0.361
#                      wcep1                   NaN        -0.119
#                      wcep2                   NaN         0.222
#                      wcep3                   NaN         0.361
#                      mperc1                  NaN       -39.652
#                      mperc2                  NaN       -10.726
#                      macrate                 NaN        -0.090
#                      mactrinf                NaN        46.368
#                      mactrsm                 NaN        -0.161
# General              wetrate                 NaN           NaN
#                      wetexp                  NaN           NaN
#                      iwetw0                  NaN           NaN
# Regionalized General damp                    NaN           NaN
#                      lp                      NaN           NaN
#                      rivvel                  NaN           NaN
#                      rrcs3                   NaN           NaN
#
#                                  03_Milk_Clay loam  11_StM_Clay  \
#                      Parameter
# Land Use             ttmp                      NaN          NaN
#                      cmlt                      NaN          NaN
#                      kc3                       NaN          NaN
#                      alb                       NaN          NaN
#                      srrcs                     NaN          NaN
# Soil Type            bfroznsoil             -2.902       -2.713
#                      bcosby                 -3.167       12.502
#                      rrcs1                   0.117       -0.163
#                      rrcs2                   0.017       -0.015
#                      srrate                 -0.016        0.181
#                      wcwp1                  -0.239       -0.186
#                      wcwp2                  -0.028       -0.214
#                      wcwp3                   0.003       -0.100
#                      wcfc1                  -0.079       -0.423
#                      wcfc2                  -0.076        0.173
#                      wcfc3                   0.239       -0.088
#                      wcep1                   0.238        0.300
#                      wcep2                   0.166        0.277
#                      wcep3                   0.178        0.403
#                      mperc1                 66.025        3.619
#                      mperc2                  3.712      -54.882
#                      macrate                -0.119       -0.140
#                      mactrinf              -28.328       46.606
#                      mactrsm                 0.009        0.165
# General              wetrate                   NaN          NaN
#                      wetexp                    NaN          NaN
#                      iwetw0                    NaN          NaN
# Regionalized General damp                      NaN          NaN
#                      lp                        NaN          NaN
#                      rivvel                    NaN          NaN
#                      rrcs3                     NaN          NaN
#
#                                  12_StM_Clay loam
#                      Parameter
# Land Use             ttmp                     NaN
#                      cmlt                     NaN
#                      kc3                      NaN
#                      alb                      NaN
#                      srrcs                    NaN
# Soil Type            bfroznsoil            -2.112
#                      bcosby                -1.910
#                      rrcs1                  0.494
#                      rrcs2                  0.000
#                      srrate                 0.332
#                      wcwp1                  0.076
#                      wcwp2                 -0.158
#                      wcwp3                  0.367
#                      wcfc1                  0.070
#                      wcfc2                  0.006
#                      wcfc3                 -0.377
#                      wcep1                 -0.876
#                      wcep2                 -0.679
#                      wcep3                 -0.100
#                      mperc1               -29.053
#                      mperc2               -45.387
#                      macrate               -0.401
#                      mactrinf              22.846
#                      mactrsm               -0.605
# General              wetrate                  NaN
#                      wetexp                   NaN
#                      iwetw0                   NaN
# Regionalized General damp                     NaN
#                      lp                       NaN
#                      rivvel                   NaN
#                      rrcs3                    NaN
